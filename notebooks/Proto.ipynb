# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
import warnings

from sklearn.cluster import OPTICS, AffinityPropagation, KMeans

# %% [markdown]
# # Obj file clustering

# %%
#path = '../../ShapeNet/plant.OBJ'
#path = '../data/processed/meshed/cropped_mesh.ply'
path = '../../3D-data/cropped_mesh_smaller.ply'

mesh = o3d.io.read_triangle_mesh(path)

# %%
o3d.visualization.draw_geometries([mesh], window_name='t')

# %%
# clustering methods
def dbscan(point_cloud, eps, mp, debug=False):
    with o3d.utility.VerbosityContextManager(
            o3d.utility.VerbosityLevel.Debug) as cm:
        labels = np.array(
            point_cloud.cluster_dbscan(eps=eps, min_points=mp, print_progress=True))

    max_label = labels.max()
    print(f"point cloud has {max_label + 1} clusters")
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
    colors[labels < 0] = 0
    point_cloud.colors = o3d.utility.Vector3dVector(colors[:, :3])

    return point_cloud

def optics(point_cloud, eps, mp, debug=False):
    
    point_cloud = np.asarray(point_cloud.points)
    clustering = OPTICS(min_samples=mp, max_eps=eps).fit(point_cloud)
    labels = clustering.labels_
    
    max_label = np.max(labels)
    print(f"point cloud has {max_label + 1} clusters")
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
    colors[labels < 0] = 0
    point_cloud = o3d.geometry.PointCloud(o3d.cpu.pybind.utility.Vector3dVector(point_cloud))
    point_cloud.colors = o3d.utility.Vector3dVector(colors[:, :3])
    
    return point_cloud

def optics(point_cloud, eps, mp, debug=False):
    
    point_cloud = np.asarray(point_cloud.points)
    clustering = OPTICS(min_samples=mp, max_eps=eps).fit(point_cloud)
    labels = clustering.labels_
    
    max_label = np.max(labels)
    print(f"point cloud has {max_label + 1} clusters")
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
    colors[labels < 0] = 0
    point_cloud = o3d.geometry.PointCloud(o3d.cpu.pybind.utility.Vector3dVector(point_cloud))
    point_cloud.colors = o3d.utility.Vector3dVector(colors[:, :3])
    
    return point_cloud

def affinity_propagation(point_cloud, damping = 0.5):
    
    point_cloud = np.asarray(point_cloud.points)
    clustering = AffinityPropagation(damping = damping).fit(point_cloud)
    
    labels = clustering.labels_
    max_label = np.max(labels)
    print(f"point cloud has {max_label + 1} clusters")
    
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
    colors[labels < 0] = 0
    point_cloud = o3d.geometry.PointCloud(o3d.cpu.pybind.utility.Vector3dVector(point_cloud))
    point_cloud.colors = o3d.utility.Vector3dVector(colors[:, :3])
    
    return point_cloud

def k_means(point_cloud, n_clusters):
    
    point_cloud = np.asarray(point_cloud.points)
    clustering = KMeans(n_clusters=n_clusters).fit(point_cloud)
    
    labels = clustering.labels_
    max_label = np.max(labels)
    print(f"point cloud has {max_label + 1} clusters")
    
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
    colors[labels < 0] = 0
    point_cloud = o3d.geometry.PointCloud(o3d.cpu.pybind.utility.Vector3dVector(point_cloud))
    point_cloud.colors = o3d.utility.Vector3dVector(colors[:, :3])
    
    return point_cloud

# %%
#pc = mesh.sample_points_uniformly(number_of_points=5000)
pc = o3d.io.read_point_cloud('../../3D-data/cropped_pcd_smaller_downsampled_and_filtered_rad20.ply')
pc = pc.uniform_down_sample(every_k_points=int(len(np.asarray(pc.points))/20000))
print(len(np.asarray(pc.points)))
#o3d.visualization.draw_geometries([pc], window_name='t')
# Out:
# 21988

# %%
ls_cluster =[]
for i in range(20):
    for j in range(5):
        print(i, j)
        ls_cluster.append(dbscan(pc,10**(i-4), 2**j, False))
# Out:
# 0 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 43975
# point cloud has 43975 clusters
# 0 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 43975
# point cloud has 43975 clusters
# 1 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 2 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 40623
# point cloud has 40623 clusters
# 2 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 3042
# point cloud has 3042 clusters
# 2 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 14
# point cloud has 14 clusters
# 2 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 2 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 3 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 9
# point cloud has 9 clusters
# 3 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 9
# point cloud has 9 clusters
# 3 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 9
# point cloud has 9 clusters
# 3 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 9
# point cloud has 9 clusters
# 3 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 9
# point cloud has 9 clusters
# 4 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 4
# [Open3D DEBUG] Precompute Neighbours

# %%
ls_cluster =[]
for i in np.arange(5,20):
    for j in range(5):
        print(i, j)
        ls_cluster.append(dbscan(pc,10**(i-4), 2**j, False))
# Out:
# 5 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 5 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 5 2
# [Open3D DEBUG] Precompute Neighbours

# %%
for num in np.arange(1,6):
    pc = o3d.io.read_point_cloud('../../3D-data/cropped_pcd_smaller_downsampled_and_filtered_rad20.ply')
    pc = pc.uniform_down_sample(every_k_points=int(len(np.asarray(pc.points))/(num*5000)))
    print(len(np.asarray(pc.points)))
    i=3
    j=4
    clustered_pc = dbscan(pc,10**(i-4), 2**j, False)
    o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# 43975
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 9
# point cloud has 9 clusters
# 43975
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 9
# point cloud has 9 clusters
# 43975
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 9
# point cloud has 9 clusters

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    ls_cluster =[]
    for i in np.arange(2,10):
        for j in np.arange(1,6):
            print(i, j)
            ls_cluster.append(optics(pc,10**(i-4), 2**j, False))
# Out:
# 0 0
# point cloud has 0 clusters
# 0 1
# point cloud has 0 clusters
# 0 2
# point cloud has 0 clusters
# 0 3
# point cloud has 0 clusters
# 0 4
# point cloud has 0 clusters
# 1 0
# point cloud has 0 clusters
# 1 1
# point cloud has 0 clusters
# 1 2
# point cloud has 0 clusters
# 1 3
# point cloud has 0 clusters
# 1 4
# point cloud has 0 clusters
# 2 0
# point cloud has 0 clusters
# 2 1
# point cloud has 805 clusters
# 2 2
# point cloud has 0 clusters
# 2 3
# point cloud has 0 clusters
# 2 4
# point cloud has 0 clusters
# 3 0
# point cloud has 0 clusters
# 3 1
# point cloud has 6035 clusters
# 3 2
# point cloud has 1684 clusters
# 3 3
# point cloud has 492 clusters
# 3 4
# point cloud has 71 clusters
# 4 0
# point cloud has 0 clusters
# 4 1
# point cloud has 6036 clusters
# 4 2
# point cloud has 1677 clusters
# 4 3
# point cloud has 495 clusters
# 4 4
# point cloud has 71 clusters
# 5 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3d728d3a78f6> in <module>
#       5         for j in range(5):
#       6             print(i, j)
# ----> 7             ls_cluster.append(optics(pc,10**(i-4), 2**j, False))
#
# <ipython-input-4-6908b3a1f539> in optics(point_cloud, eps, mp, debug)
#      32
#      33     point_cloud = np.asarray(point_cloud.points)
# ---> 34     clustering = OPTICS(min_samples=mp, max_eps=eps).fit(point_cloud)
#      35     labels = clustering.labels_
#      36
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_optics.py in fit(self, X, y)
#     252
#     253         (self.ordering_, self.core_distances_, self.reachability_,
# --> 254          self.predecessor_) = compute_optics_graph(
#     255              X=X, min_samples=self.min_samples, algorithm=self.algorithm,
#     256              leaf_size=self.leaf_size, metric=self.metric,
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_optics.py in compute_optics_graph(X, min_samples, max_eps, metric, p, metric_params, algorithm, leaf_size, n_jobs)
#     469     # the original OPTICS that only used epsilon range queries.
#     470     # TODO: handle working_memory somehow?
# --> 471     core_distances_ = _compute_core_distances_(X=X, neighbors=nbrs,
#     472                                                min_samples=min_samples,
#     473                                                working_memory=None)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_optics.py in _compute_core_distances_(X, neighbors, min_samples, working_memory)
#     334     slices = gen_batches(n_samples, chunk_n_rows)
#     335     for sl in slices:
# --> 336         core_distances[sl] = neighbors.kneighbors(
#     337             X[sl], min_samples)[0][:, -1]
#     338     return core_distances
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     703                 kwds = self.effective_metric_params_
#     704
# --> 705             chunked_results = list(pairwise_distances_chunked(
#     706                 X, self._fit_X, reduce_func=reduce_func,
#     707                 metric=self.effective_metric_, n_jobs=n_jobs,
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1621         else:
#    1622             X_chunk = X[sl]
# -> 1623         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
#    1624                                      n_jobs=n_jobs, **kwds)
#    1625         if ((X is Y or Y is None)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1788         func = partial(distance.cdist, metric=metric, **kwds)
#    1789
# -> 1790     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1791
#    1792
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1357
#    1358     if effective_n_jobs(n_jobs) == 1:
# -> 1359         return func(X, Y, **kwds)
#    1360
#    1361     # enforce a threading backend to prevent data communication overhead
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     311     else:
#     312         # if dtype is already float64, no need to chunk and upcast
# --> 313         distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     314         distances += XX
#     315         distances += YY
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     150             ret = np.dot(a, b)
#     151     else:
# --> 152         ret = a @ b
#     153
#     154     if (sparse.issparse(a) and sparse.issparse(b)
#
# KeyboardInterrupt:

# %%
i=3
j=5
clustered_pc = optics(pc,10**(i-4), 2**j, False)
o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# point cloud has 11 clusters

# %%
for num in np.arange(1,6):
    pc = o3d.io.read_point_cloud('../../3D-data/cropped_pcd_smaller_downsampled_and_filtered_rad20.ply')
    pc = pc.uniform_down_sample(every_k_points=int(len(np.asarray(pc.points))/(num*5000)))
    print(len(np.asarray(pc.points)))
    i=3
    j=4
    clustered_pc = optics(pc,10**(i-4), 2**j, False)
    o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# 5497
# point cloud has 56 clusters
# 10994
# point cloud has 70 clusters
# 21988
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-45a83bbed13a> in <module>
#       5     i=3
#       6     j=4
# ----> 7     clustered_pc = optics(pc,10**(i-4), 2**j, False)
#       8     o3d.visualization.draw_geometries([clustered_pc], window_name='t')
#
# <ipython-input-4-6908b3a1f539> in optics(point_cloud, eps, mp, debug)
#      32
#      33     point_cloud = np.asarray(point_cloud.points)
# ---> 34     clustering = OPTICS(min_samples=mp, max_eps=eps).fit(point_cloud)
#      35     labels = clustering.labels_
#      36
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_optics.py in fit(self, X, y)
#     252
#     253         (self.ordering_, self.core_distances_, self.reachability_,
# --> 254          self.predecessor_) = compute_optics_graph(
#     255              X=X, min_samples=self.min_samples, algorithm=self.algorithm,
#     256              leaf_size=self.leaf_size, metric=self.metric,
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_optics.py in compute_optics_graph(X, min_samples, max_eps, metric, p, metric_params, algorithm, leaf_size, n_jobs)
#     490         ordering[ordering_idx] = point
#     491         if core_distances_[point] != np.inf:
# --> 492             _set_reach_dist(core_distances_=core_distances_,
#     493                             reachability_=reachability_,
#     494                             predecessor_=predecessor_,
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_optics.py in _set_reach_dist(core_distances_, reachability_, predecessor_, point_index, processed, X, nbrs, metric, metric_params, p, max_eps)
#     534
#     535     rdists = np.maximum(dists, core_distances_[point_index])
# --> 536     improved = np.where(rdists < np.take(reachability_, unproc))
#     537     reachability_[unproc[improved]] = rdists[improved]
#     538     predecessor_[unproc[improved]] = point_index
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    ls_cluster =[]
    for i in range(10):
        for j in range(5):
            print(i, j)
            ls_cluster.append(optics(pc,10**(i-4), 2**j, False))
# Out:
# 0 0
# point cloud has 0 clusters
# 0 1
# point cloud has 0 clusters
# 0 2
# point cloud has 0 clusters
# 0 3
# point cloud has 0 clusters
# 0 4
# point cloud has 0 clusters
# 1 0
# point cloud has 0 clusters
# 1 1
# point cloud has 0 clusters
# 1 2
# point cloud has 0 clusters
# 1 3
# point cloud has 0 clusters
# 1 4
# point cloud has 0 clusters
# 2 0
# point cloud has 0 clusters
# 2 1
# point cloud has 15 clusters
# 2 2
# point cloud has 0 clusters
# 2 3
# point cloud has 0 clusters
# 2 4
# point cloud has 0 clusters
# 3 0
# point cloud has 0 clusters
# 3 1
# point cloud has 1519 clusters
# 3 2
# point cloud has 471 clusters
# 3 3
# point cloud has 106 clusters
# 3 4
# point cloud has 2 clusters
# 4 0
# point cloud has 0 clusters
# 4 1
# point cloud has 1526 clusters
# 4 2
# point cloud has 486 clusters
# 4 3
# point cloud has 150 clusters
# 4 4
# point cloud has 31 clusters
# 5 0
# point cloud has 1 clusters
# 5 1
# point cloud has 1526 clusters
# 5 2
# point cloud has 486 clusters
# 5 3
# point cloud has 150 clusters
# 5 4
# point cloud has 31 clusters
# 6 0
# point cloud has 1 clusters
# 6 1
# point cloud has 1526 clusters
# 6 2
# point cloud has 486 clusters
# 6 3
# point cloud has 150 clusters
# 6 4
# point cloud has 31 clusters
# 7 0
# point cloud has 1 clusters
# 7 1
# point cloud has 1526 clusters
# 7 2
# point cloud has 486 clusters
# 7 3
# point cloud has 150 clusters
# 7 4
# point cloud has 31 clusters
# 8 0
# point cloud has 1 clusters
# 8 1
# point cloud has 1526 clusters
# 8 2
# point cloud has 486 clusters
# 8 3
# point cloud has 150 clusters
# 8 4
# point cloud has 31 clusters
# 9 0
# point cloud has 1 clusters
# 9 1
# point cloud has 1526 clusters
# 9 2
# point cloud has 486 clusters
# 9 3
# point cloud has 150 clusters
# 9 4
# point cloud has 31 clusters

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    ls_cluster =[]
    for i in np.arange(4,20):
        for j in np.arange(4.5,5.5,0.1):
            print(i, j)
            ls_cluster.append(optics(pc,10**(i-4), int(2**j), False))
# Out:
# 0 4.5
# point cloud has 0 clusters
# 0 4.6
# point cloud has 0 clusters
# 0 4.699999999999999
# point cloud has 0 clusters
# 0 4.799999999999999
# point cloud has 0 clusters
# 0 4.899999999999999
# point cloud has 0 clusters
# 0 4.999999999999998
# point cloud has 0 clusters
# 0 5.099999999999998
# point cloud has 0 clusters
# 0 5.1999999999999975
# point cloud has 0 clusters
# 0 5.299999999999997
# point cloud has 0 clusters
# 0 5.399999999999997
# point cloud has 0 clusters
# 1 4.5
# point cloud has 0 clusters
# 1 4.6
# point cloud has 0 clusters
# 1 4.699999999999999
# point cloud has 0 clusters
# 1 4.799999999999999
# point cloud has 0 clusters
# 1 4.899999999999999
# point cloud has 0 clusters
# 1 4.999999999999998
# point cloud has 0 clusters
# 1 5.099999999999998
# point cloud has 0 clusters
# 1 5.1999999999999975
# point cloud has 0 clusters
# 1 5.299999999999997
# point cloud has 0 clusters
# 1 5.399999999999997
# point cloud has 0 clusters
# 2 4.5
# point cloud has 0 clusters
# 2 4.6
# point cloud has 0 clusters
# 2 4.699999999999999
# point cloud has 0 clusters
# 2 4.799999999999999
# point cloud has 0 clusters
# 2 4.899999999999999
# point cloud has 0 clusters
# 2 4.999999999999998
# point cloud has 0 clusters
# 2 5.099999999999998
# point cloud has 0 clusters
# 2 5.1999999999999975
# point cloud has 0 clusters
# 2 5.299999999999997
# point cloud has 0 clusters
# 2 5.399999999999997
# point cloud has 0 clusters
# 3 4.5
# point cloud has 0 clusters
# 3 4.6
# point cloud has 0 clusters
# 3 4.699999999999999
# point cloud has 0 clusters
# 3 4.799999999999999
# point cloud has 0 clusters
# 3 4.899999999999999
# point cloud has 0 clusters
# 3 4.999999999999998
# point cloud has 0 clusters
# 3 5.099999999999998
# point cloud has 0 clusters
# 3 5.1999999999999975
# point cloud has 0 clusters
# 3 5.299999999999997
# point cloud has 0 clusters
# 3 5.399999999999997
# point cloud has 0 clusters
# 4 4.5
# point cloud has 15 clusters
# 4 4.6
# point cloud has 18 clusters
# 4 4.699999999999999
# point cloud has 11 clusters
# 4 4.799999999999999
# point cloud has 9 clusters
# 4 4.899999999999999
# point cloud has 11 clusters
# 4 4.999999999999998
# point cloud has 10 clusters
# 4 5.099999999999998
# point cloud has 9 clusters
# 4 5.1999999999999975
# point cloud has 7 clusters
# 4 5.299999999999997
# point cloud has 7 clusters
# 4 5.399999999999997
# point cloud has 5 clusters
# 5 4.5
# point cloud has 15 clusters
# 5 4.6
# point cloud has 18 clusters
# 5 4.699999999999999
# point cloud has 11 clusters
# 5 4.799999999999999
# point cloud has 9 clusters
# 5 4.899999999999999
# point cloud has 11 clusters
# 5 4.999999999999998
# point cloud has 10 clusters
# 5 5.099999999999998
# point cloud has 9 clusters
# 5 5.1999999999999975
# point cloud has 7 clusters
# 5 5.299999999999997
# point cloud has 7 clusters
# 5 5.399999999999997
# point cloud has 5 clusters
# 6 4.5
# point cloud has 15 clusters
# 6 4.6
# point cloud has 18 clusters
# 6 4.699999999999999
# point cloud has 11 clusters
# 6 4.799999999999999
# point cloud has 9 clusters
# 6 4.899999999999999
# point cloud has 11 clusters
# 6 4.999999999999998
# point cloud has 10 clusters
# 6 5.099999999999998
# point cloud has 9 clusters
# 6 5.1999999999999975
# point cloud has 7 clusters
# 6 5.299999999999997
# point cloud has 7 clusters
# 6 5.399999999999997
# point cloud has 5 clusters
# 7 4.5
# point cloud has 15 clusters
# 7 4.6
# point cloud has 18 clusters
# 7 4.699999999999999
# point cloud has 11 clusters
# 7 4.799999999999999
# point cloud has 9 clusters
# 7 4.899999999999999
# point cloud has 11 clusters
# 7 4.999999999999998
# point cloud has 10 clusters
# 7 5.099999999999998
# point cloud has 9 clusters
# 7 5.1999999999999975
# point cloud has 7 clusters
# 7 5.299999999999997
# point cloud has 7 clusters
# 7 5.399999999999997
# point cloud has 5 clusters
# 8 4.5
# point cloud has 15 clusters
# 8 4.6
# point cloud has 18 clusters
# 8 4.699999999999999
# point cloud has 11 clusters
# 8 4.799999999999999
# point cloud has 9 clusters
# 8 4.899999999999999
# point cloud has 11 clusters
# 8 4.999999999999998
# point cloud has 10 clusters
# 8 5.099999999999998
# point cloud has 9 clusters
# 8 5.1999999999999975
# point cloud has 7 clusters
# 8 5.299999999999997
# point cloud has 7 clusters
# 8 5.399999999999997
# point cloud has 5 clusters
# 9 4.5
# point cloud has 15 clusters
# 9 4.6
# point cloud has 18 clusters
# 9 4.699999999999999
# point cloud has 11 clusters
# 9 4.799999999999999
# point cloud has 9 clusters
# 9 4.899999999999999
# point cloud has 11 clusters
# 9 4.999999999999998
# point cloud has 10 clusters
# 9 5.099999999999998
# point cloud has 9 clusters
# 9 5.1999999999999975
# point cloud has 7 clusters
# 9 5.299999999999997
# point cloud has 7 clusters
# 9 5.399999999999997
# point cloud has 5 clusters
# 10 4.5
# point cloud has 15 clusters
# 10 4.6
# point cloud has 18 clusters
# 10 4.699999999999999
# point cloud has 11 clusters
# 10 4.799999999999999
# point cloud has 9 clusters
# 10 4.899999999999999
# point cloud has 11 clusters
# 10 4.999999999999998
# point cloud has 10 clusters
# 10 5.099999999999998
# point cloud has 9 clusters
# 10 5.1999999999999975
# point cloud has 7 clusters
# 10 5.299999999999997
# point cloud has 7 clusters
# 10 5.399999999999997
# point cloud has 5 clusters
# 11 4.5
# point cloud has 15 clusters
# 11 4.6
# point cloud has 18 clusters
# 11 4.699999999999999
# point cloud has 11 clusters
# 11 4.799999999999999
# point cloud has 9 clusters
# 11 4.899999999999999
# point cloud has 11 clusters
# 11 4.999999999999998
# point cloud has 10 clusters
# 11 5.099999999999998
# point cloud has 9 clusters
# 11 5.1999999999999975
# point cloud has 7 clusters
# 11 5.299999999999997
# point cloud has 7 clusters
# 11 5.399999999999997
# point cloud has 5 clusters
# 12 4.5
# point cloud has 15 clusters
# 12 4.6
# point cloud has 18 clusters
# 12 4.699999999999999
# point cloud has 11 clusters
# 12 4.799999999999999
# point cloud has 9 clusters
# 12 4.899999999999999
# point cloud has 11 clusters
# 12 4.999999999999998
# point cloud has 10 clusters
# 12 5.099999999999998
# point cloud has 9 clusters
# 12 5.1999999999999975
# point cloud has 7 clusters
# 12 5.299999999999997
# point cloud has 7 clusters
# 12 5.399999999999997
# point cloud has 5 clusters
# 13 4.5
# point cloud has 15 clusters
# 13 4.6
# point cloud has 18 clusters
# 13 4.699999999999999
# point cloud has 11 clusters
# 13 4.799999999999999
# point cloud has 9 clusters
# 13 4.899999999999999
# point cloud has 11 clusters
# 13 4.999999999999998
# point cloud has 10 clusters
# 13 5.099999999999998
# point cloud has 9 clusters
# 13 5.1999999999999975
# point cloud has 7 clusters
# 13 5.299999999999997
# point cloud has 7 clusters
# 13 5.399999999999997
# point cloud has 5 clusters
# 14 4.5
# point cloud has 15 clusters
# 14 4.6
# point cloud has 18 clusters
# 14 4.699999999999999
# point cloud has 11 clusters
# 14 4.799999999999999
# point cloud has 9 clusters
# 14 4.899999999999999
# point cloud has 11 clusters
# 14 4.999999999999998
# point cloud has 10 clusters
# 14 5.099999999999998
# point cloud has 9 clusters
# 14 5.1999999999999975
# point cloud has 7 clusters
# 14 5.299999999999997
# point cloud has 7 clusters
# 14 5.399999999999997
# point cloud has 5 clusters
# 15 4.5
# point cloud has 15 clusters
# 15 4.6
# point cloud has 18 clusters
# 15 4.699999999999999
# point cloud has 11 clusters
# 15 4.799999999999999
# point cloud has 9 clusters
# 15 4.899999999999999
# point cloud has 11 clusters
# 15 4.999999999999998
# point cloud has 10 clusters
# 15 5.099999999999998
# point cloud has 9 clusters
# 15 5.1999999999999975
# point cloud has 7 clusters
# 15 5.299999999999997
# point cloud has 7 clusters
# 15 5.399999999999997
# point cloud has 5 clusters
# 16 4.5
# point cloud has 15 clusters
# 16 4.6
# point cloud has 18 clusters
# 16 4.699999999999999
# point cloud has 11 clusters
# 16 4.799999999999999
# point cloud has 9 clusters
# 16 4.899999999999999
# point cloud has 11 clusters
# 16 4.999999999999998
# point cloud has 10 clusters
# 16 5.099999999999998
# point cloud has 9 clusters
# 16 5.1999999999999975
# point cloud has 7 clusters
# 16 5.299999999999997
# point cloud has 7 clusters
# 16 5.399999999999997
# point cloud has 5 clusters
# 17 4.5
# point cloud has 15 clusters
# 17 4.6
# point cloud has 18 clusters
# 17 4.699999999999999
# point cloud has 11 clusters
# 17 4.799999999999999
# point cloud has 9 clusters
# 17 4.899999999999999
# point cloud has 11 clusters
# 17 4.999999999999998
# point cloud has 10 clusters
# 17 5.099999999999998
# point cloud has 9 clusters
# 17 5.1999999999999975
# point cloud has 7 clusters
# 17 5.299999999999997
# point cloud has 7 clusters
# 17 5.399999999999997
# point cloud has 5 clusters
# 18 4.5
# point cloud has 15 clusters
# 18 4.6
# point cloud has 18 clusters
# 18 4.699999999999999
# point cloud has 11 clusters
# 18 4.799999999999999
# point cloud has 9 clusters
# 18 4.899999999999999
# point cloud has 11 clusters
# 18 4.999999999999998
# point cloud has 10 clusters
# 18 5.099999999999998
# point cloud has 9 clusters
# 18 5.1999999999999975
# point cloud has 7 clusters
# 18 5.299999999999997
# point cloud has 7 clusters
# 18 5.399999999999997
# point cloud has 5 clusters
# 19 4.5
# point cloud has 15 clusters
# 19 4.6
# point cloud has 18 clusters
# 19 4.699999999999999
# point cloud has 11 clusters
# 19 4.799999999999999
# point cloud has 9 clusters
# 19 4.899999999999999
# point cloud has 11 clusters
# 19 4.999999999999998
# point cloud has 10 clusters
# 19 5.099999999999998
# point cloud has 9 clusters
# 19 5.1999999999999975
# point cloud has 7 clusters
# 19 5.299999999999997
# point cloud has 7 clusters
# 19 5.399999999999997
# point cloud has 5 clusters

# %%
pc = o3d.io.read_point_cloud('../../3D-data/cropped_pcd_downsampled_and_filtered_rad16.ply')
pc = pc.uniform_down_sample(every_k_points=int(len(np.asarray(pc.points))/10000))
print(len(np.asarray(pc.points)))
# Out:
# 10878

# %%
pc = o3d.io.read_point_cloud('../../3D-data/cropped_pcd_smaller_downsampled_and_filtered_rad20.ply')
pc = pc.uniform_down_sample(every_k_points=int(len(np.asarray(pc.points))/10000))
print(len(np.asarray(pc.points)))
# Out:
# 10994

# %%
# TO try: 4+,5
i = 13 #3
j = 4.9 #5
clustered_pc = optics(pc,10**(i-4), int(2**j), False) 
o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# point cloud has 17 clusters

# %%
clustered_pc = k_means(pc,n_clusters=10) 
o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# point cloud has 10 clusters

# %%
import warnings

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    ls_cluster = []
    for i in np.arange(90,100):    
        print()
        print("damping = " + str(i/100))
        ls_cluster.append(affinity_propagation(pc, damping = i/100))

    #o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# damping = 0.9
#
# point cloud has 68 clusters
# damping = 0.91
#
# point cloud has 68 clusters
# damping = 0.92
#
# point cloud has 70 clusters
# damping = 0.93
#
# point cloud has 72 clusters
# damping = 0.94
#
# point cloud has 70 clusters
# damping = 0.95
#
# point cloud has 73 clusters
# damping = 0.96
#
# point cloud has 72 clusters
# damping = 0.97
#
# point cloud has 73 clusters
# damping = 0.98
#
# point cloud has 0 clusters
# damping = 0.99
#
# point cloud has 0 clusters

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    ls_cluster = []
    for i in np.arange(70,90,4):    
        print()
        print("damping = " + str(i/100))
        ls_cluster.append(affinity_propagation(pc, damping = i/100))

    #o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# damping = 0.7
#
# point cloud has 75 clusters
# damping = 0.74
#
# point cloud has 72 clusters
# damping = 0.78
#
# point cloud has 72 clusters
# damping = 0.82
#
# point cloud has 72 clusters
# damping = 0.86
#
# point cloud has 67 clusters

# %%
#pc_clustered = dbscan(pc, False, 0)
#o3d.visualization.draw_geometries([pc_clustered], window_name='t')
# Out:
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 5000
# point cloud has 5000 clusters

# %%
ls_cluster =[]
for i in range(20):
    for j in range(5):
        print(i, j)
        ls_cluster.append(dbscan(pc,10**(i-4), 2**j, False))
# Out:
# 0 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 108776
# point cloud has 108776 clusters
# 0 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 108776
# point cloud has 108776 clusters
# 1 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 2 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 101103
# point cloud has 101103 clusters
# 2 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 7048
# point cloud has 7048 clusters
# 2 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 17
# point cloud has 17 clusters
# 2 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 2 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 3 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 13
# point cloud has 13 clusters
# 3 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 13
# point cloud has 13 clusters
# 3 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 12
# point cloud has 12 clusters
# 3 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 12
# point cloud has 12 clusters
# 3 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 13
# point cloud has 13 clusters
# 4 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters

# %%
clustered_pc = dbscan(pc,0.1, 32, False) # 10**(3-4) 2**5
o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 12
# point cloud has 12 clusters

# %%
ls_cluster =[]
for i in range(20):
    for j in range(5):
        print(i, j)
        ls_cluster.append(dbscan(pc,10**(i-4), 2**j, False))
# Out:
# 0 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 5000
# point cloud has 5000 clusters
# 0 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 5000
# point cloud has 5000 clusters
# 1 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 2 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 4983
# point cloud has 4983 clusters
# 2 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 17
# point cloud has 17 clusters
# 2 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 2 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 2 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 3 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 710
# point cloud has 710 clusters
# 3 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 451
# point cloud has 451 clusters
# 3 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 300
# point cloud has 300 clusters
# 3 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 65
# point cloud has 65 clusters
# 3 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 5 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 5 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 5 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 5 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 5 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 6 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 6 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 6 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 6 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 6 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 7 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 7 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 7 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 7 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 7 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 8 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 8 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 8 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 8 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 8 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 9 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 9 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 9 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 9 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 9 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 10 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 10 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 10 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 10 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 10 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 11 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 11 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 11 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 11 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 11 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 12 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 12 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 12 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 12 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 12 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 13 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 13 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 13 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 13 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 13 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 14 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 14 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 14 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 14 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 14 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 15 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 15 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 15 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 15 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 15 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 16 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 16 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 16 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 16 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 16 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 17 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 17 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 17 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 17 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 17 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 18 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 18 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 18 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 18 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 18 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 19 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 19 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 19 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 19 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 19 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters

# %%
pc = dbscan(pc,10**(3-4), 10, False)
# Out:
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 14
# point cloud has 14 clusters

# %%
o3d.visualization.draw_geometries([pc], window_name='t')

# %% [markdown]
# # Mesh Topology

# %%
np.asarray(mesh.vertices)
# Out:
# array([[ 1.20654202, -1.57696915,  1.99949074],
#        [ 1.1950655 , -1.59717941,  1.99949074],
#        [ 1.21610451, -1.5622406 ,  1.99949074],
#        ...,
#        [ 2.03662682,  1.5753597 ,  7.90054607],
#        [ 2.03973579,  1.57888794,  7.90506697],
#        [ 2.05755806,  1.59246469,  7.92410421]])

# %%
triangle_array = np.asarray(mesh.triangles)

# %%
triangle_array.histogram()
plt.histogram(triangle_array)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-75d8dc8b03c2> in <module>
# ----> 1 triangle_array.histogram()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'histogram'

# %%
np.histogram(triangle_array.flatten())
# Out:
# (array([336506, 337247, 336426, 336290, 336041, 336279, 336055, 335510,
#         334785, 315013]),
#  array([     0. ,  55983.9, 111967.8, 167951.7, 223935.6, 279919.5,
#         335903.4, 391887.3, 447871.2, 503855.1, 559839. ]))

# %%
plt.hist(triangle_array.flatten(), bins=len(triangle_array.flatten()))

# %%
len(triangle_array.flatten())
# Out:
# 3340152

# %%
h = np.histogram(triangle_array.flatten(), bins=len(triangle_array.flatten()))

# %%
h[0].max()
# Out:
# 13

# %%
mesh.compute_adjacency_list()
# Out:
# TriangleMesh with 559840 points and 1113384 triangles.

# %%
import sklearn.cluster as C

# %%
C.SpectralClustering()
# Out:
# SpectralClustering()
