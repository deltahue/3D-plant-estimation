# %%
import open3d as o3d
import numpy as np
import matplotlib.pyplot as plt
import time
import warnings # To suppress warnings from OPTICS

from sklearn.cluster import DBSCAN, KMeans, OPTICS

import colorsys

# %% [markdown]
# # Obj file clustering

# %%
# DBSCAN with color (works with 4D grayscale and 6D color)
def dbscan_color(point_cloud, pc_colors, eps, mp, debug=False):
    with o3d.utility.VerbosityContextManager(
            o3d.utility.VerbosityLevel.Debug) as cm:
        
        clustering = DBSCAN(eps=eps, min_samples=mp, n_jobs=-1).fit(pc_colors)
        labels = clustering.labels_
        print("clustering: ", clustering)
        print("labels: ", labels)

    max_label = labels.max()
    print(f"point cloud has {max_label + 1} clusters")
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
    print("colors: ", colors)
    colors[labels < 0] = 0
    point_cloud.colors = o3d.utility.Vector3dVector(colors[:, :3])

    return point_cloud, labels


# DBSCAN without color
def dbscan(point_cloud, eps, mp, debug=False):

    with o3d.utility.VerbosityContextManager(
            o3d.utility.VerbosityLevel.Debug) as cm:
        labels = np.array(
            point_cloud.cluster_dbscan(eps=eps, min_points=mp, print_progress=True))

    max_label = labels.max()
    print(f"point cloud has {max_label + 1} clusters")
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
    colors[labels < 0] = 0
    point_cloud.colors = o3d.utility.Vector3dVector(colors[:, :3])

    return point_cloud, labels

def optics_color(point_cloud, pc_colors, eps, mp, debug=False):
    
    point_cloud = np.asarray(point_cloud.points)
    clustering = OPTICS(min_samples=mp, max_eps=eps, n_jobs=-1).fit(pc_colors)
    labels = clustering.labels_
    
    max_label = np.max(labels)
    print(f"point cloud has {max_label + 1} clusters")
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
    colors[labels < 0] = 0
    point_cloud = o3d.geometry.PointCloud(o3d.cpu.pybind.utility.Vector3dVector(point_cloud))
    point_cloud.colors = o3d.utility.Vector3dVector(colors[:, :3])
    
    return point_cloud, labels

# Try k_means for fun
def k_means_color(point_cloud, pc_colors, n_clusters):
    
    point_cloud = np.asarray(point_cloud.points)
    clustering = KMeans(n_clusters=n_clusters, n_jobs=-1).fit(pc_colors)
    
    labels = clustering.labels_
    max_label = np.max(labels)
    print(f"point cloud has {max_label + 1} clusters")
    
    colors = plt.get_cmap("tab20")(labels / (max_label if max_label > 0 else 1))
    colors[labels < 0] = 0
    point_cloud = o3d.geometry.PointCloud(o3d.cpu.pybind.utility.Vector3dVector(point_cloud))
    point_cloud.colors = o3d.utility.Vector3dVector(colors[:, :3])
    
    return point_cloud, labels

# %%
#pc = o3d.io.read_point_cloud('../../3D-data/cropped_pcd_smaller_downsampled_and_filtered_rad20.ply')
#pc = o3d.io.read_point_cloud('../../3D-data/cropped_pcd_filtered_rad20_0p1_nopot.ply')
#pc = o3d.io.read_point_cloud('../../3D-data/cropped_pcd_filtered_newplant.ply')
#pc = o3d.io.read_point_cloud('./cropped_pcd_filtered_newplant.ply')
#pc = o3d.io.read_point_cloud('../../3D-data/cropped_pcd_filtered_avocado_rad20_0p1.ply')
#pc = o3d.io.read_point_cloud('./cropped_pcd_filtered_avocado_rad20_0p1.ply')
pc = o3d.io.read_point_cloud('./cropped_pcd_filtered_rad20_0p1_nopot.ply')
pc = pc.uniform_down_sample(every_k_points=int(len(np.asarray(pc.points))/15000))
print(len(np.asarray(pc.points)))
#o3d.visualization.draw_geometries([pc], window_name='t')
# Out:
# 20205

# %%
pc_colors = np.asarray(pc.colors) # RGB colors

pc_gray   = 0.299*pc_colors[:,0] + 0.587*pc_colors[:,1] + 0.114*pc_colors[:,2] 
pc_gray     = np.c_[np.asarray(pc.points), pc_gray] # grayscale cloud

for i in range(len(pc_colors)):
    pc_colors[i] = colorsys.rgb_to_hsv(pc_colors[i,0],pc_colors[i,1],pc_colors[i,2]) # Convert to hsv
pc_colors = np.c_[np.asarray(pc.points), pc_colors]  # color cloud

# %%
ls_cluster =[]
print(time.asctime())
for i in range(5):
    for j in range(6):
        print(i, j)
        ls_cluster.append(dbscan_color(pc, pc_colors, 10**(i-4), 2**j))
print(time.asctime())
# Out:
# Tue May  4 16:13:23 2021
# 0 0
# clustering:  DBSCAN(eps=0.0001, min_samples=1, n_jobs=-1)
# labels:  [    0     1     2 ... 20202 20203 20204]
# point cloud has 20205 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.61960784 0.85490196 0.89803922 1.        ]
#  [0.61960784 0.85490196 0.89803922 1.        ]
#  [0.61960784 0.85490196 0.89803922 1.        ]]
# 0 1
# clustering:  DBSCAN(eps=0.0001, min_samples=2, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 0 2
# clustering:  DBSCAN(eps=0.0001, min_samples=4, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 0 3
# clustering:  DBSCAN(eps=0.0001, min_samples=8, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 0 4
# clustering:  DBSCAN(eps=0.0001, min_samples=16, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 0 5
# clustering:  DBSCAN(eps=0.0001, min_samples=32, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 1 0
# clustering:  DBSCAN(eps=0.001, min_samples=1, n_jobs=-1)
# labels:  [    0     1     2 ... 20202 20203 20204]
# point cloud has 20205 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.61960784 0.85490196 0.89803922 1.        ]
#  [0.61960784 0.85490196 0.89803922 1.        ]
#  [0.61960784 0.85490196 0.89803922 1.        ]]
# 1 1
# clustering:  DBSCAN(eps=0.001, min_samples=2, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 1 2
# clustering:  DBSCAN(eps=0.001, min_samples=4, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 1 3
# clustering:  DBSCAN(eps=0.001, min_samples=8, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 1 4
# clustering:  DBSCAN(eps=0.001, min_samples=16, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 1 5
# clustering:  DBSCAN(eps=0.001, min_samples=32, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 2 0
# clustering:  DBSCAN(eps=0.01, min_samples=1, n_jobs=-1)
# labels:  [    0     1     2 ... 20034 20035 20036]
# point cloud has 20037 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.61960784 0.85490196 0.89803922 1.        ]
#  [0.61960784 0.85490196 0.89803922 1.        ]
#  [0.61960784 0.85490196 0.89803922 1.        ]]
# 2 1
# clustering:  DBSCAN(eps=0.01, min_samples=2, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 168 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 2 2
# clustering:  DBSCAN(eps=0.01, min_samples=4, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 2 3
# clustering:  DBSCAN(eps=0.01, min_samples=8, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 2 4
# clustering:  DBSCAN(eps=0.01, min_samples=16, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 2 5
# clustering:  DBSCAN(eps=0.01, min_samples=32, n_jobs=-1)
# labels:  [-1 -1 -1 ... -1 -1 -1]
# point cloud has 0 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 3 0
# clustering:  DBSCAN(eps=0.1, min_samples=1, n_jobs=-1)
# labels:  [0 0 0 ... 0 0 7]
# point cloud has 171 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 3 1
# clustering:  DBSCAN(eps=0.1, min_samples=2, n_jobs=-1)
# labels:  [0 0 0 ... 0 0 5]
# point cloud has 85 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.68235294 0.78039216 0.90980392 1.        ]]
# 3 2
# clustering:  DBSCAN(eps=0.1, min_samples=4, n_jobs=-1)
# labels:  [0 0 0 ... 0 0 3]
# point cloud has 43 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.68235294 0.78039216 0.90980392 1.        ]]
# 3 3
# clustering:  DBSCAN(eps=0.1, min_samples=8, n_jobs=-1)
# labels:  [ 0 -1  0 ...  0  0  5]
# point cloud has 35 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [1.         0.49803922 0.05490196 1.        ]]
# 3 4
# clustering:  DBSCAN(eps=0.1, min_samples=16, n_jobs=-1)
# labels:  [ 0 -1  0 ...  4  1  5]
# point cloud has 27 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [1.         0.73333333 0.47058824 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [1.         0.73333333 0.47058824 1.        ]]
# 3 5
# clustering:  DBSCAN(eps=0.1, min_samples=32, n_jobs=-1)
# labels:  [15 -1 -1 ...  3  1  8]
# point cloud has 23 clusters
# colors:  [[0.96862745 0.71372549 0.82352941 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [1.         0.49803922 0.05490196 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [1.         0.59607843 0.58823529 1.        ]]
# 4 0
# clustering:  DBSCAN(eps=1, min_samples=1, n_jobs=-1)
# labels:  [0 0 0 ... 0 0 0]
# point cloud has 3 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 4 1
# clustering:  DBSCAN(eps=1, min_samples=2, n_jobs=-1)
# labels:  [0 0 0 ... 0 0 0]
# point cloud has 3 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 4 2
# clustering:  DBSCAN(eps=1, min_samples=4, n_jobs=-1)
# labels:  [0 0 0 ... 0 0 0]
# point cloud has 3 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 4 3
# clustering:  DBSCAN(eps=1, min_samples=8, n_jobs=-1)
# labels:  [0 0 0 ... 0 0 0]
# point cloud has 3 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 4 4
# clustering:  DBSCAN(eps=1, min_samples=16, n_jobs=-1)
# labels:  [0 0 0 ... 0 0 0]
# point cloud has 3 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# 4 5
# clustering:  DBSCAN(eps=1, min_samples=32, n_jobs=-1)
# labels:  [0 0 0 ... 0 0 0]
# point cloud has 2 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]]
# Tue May  4 16:13:34 2021

# %%
i=3
j=4.2
clustered_pc, labels = dbscan_color(pc, pc_colors, 10**(i-4), 2**j, False) # was 6D
o3d.visualization.draw_geometries([clustered_pc], window_name='t')

'''
i=3
j=5
clustered_pc, labels = dbscan_4D(pc, pc_4D, 10**(i-4), 2**j, False)
o3d.visualization.draw_geometries([clustered_pc], window_name='t')
'''
# Out:
# clustering:  DBSCAN(eps=0.1, min_samples=18.37917367995256, n_jobs=-1)
# labels:  [ 1 -1 -1 ...  5  2  6]
# point cloud has 22 clusters
# colors:  [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  [0.12156863 0.46666667 0.70588235 1.        ]
#  ...
#  [0.17254902 0.62745098 0.17254902 1.        ]
#  [0.68235294 0.78039216 0.90980392 1.        ]
#  [0.59607843 0.8745098  0.54117647 1.        ]]
# "\ni=3\nj=5\nclustered_pc, labels = dbscan_4D(pc, pc_4D, 10**(i-4), 2**j, False)\no3d.visualization.draw_geometries([clustered_pc], window_name='t')\n"

# %%
mask = [la==5 for la in labels]
print(np.asarray(pc.points))
points = np.asarray(pc.points)
print(points.shape)
#print(mask)
# Out:
# [[ 2.47904706  0.73929596  5.27709103]
#  [ 2.58115005  0.64347792  5.25052261]
#  [ 2.58010936  0.62552333  5.24653316]
#  ...
#  [ 3.09278202 -1.50414658  4.21751118]
#  [ 0.70030665 -1.11335313  4.36267757]
#  [ 1.29057574 -2.88004947  3.18366849]]
# (20205, 3)

# %%
#print(points[mask])
selected = points[mask]
print(selected)
print(selected.shape)

pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(selected)

o3d.visualization.draw_geometries([pcd], window_name='t')

o3d.io.write_point_cloud("leaf-test.ply", pcd)
# Out:
# [[ 1.81668663 -0.67773604  2.74649405]
#  [ 2.43406105 -1.04012847  3.29532599]
#  [ 2.13472462 -1.01650572  3.04951   ]
#  ...
#  [ 2.63125873 -1.21123767  3.34649611]
#  [ 3.08506816 -0.75395831  3.45663347]
#  [ 3.09278202 -1.50414658  4.21751118]]
# (4555, 3)
# True

# %%
print(len(labels))
print(len(pc.points))
# Out:
# 20205
# 20205

# %%
i=2
j=1
clustered_pc, labels = dbscan(pc, 10**(i-4), 2**j, False) # was 6D
o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 723
# point cloud has 723 clusters

# %%
# Ignore warnings and make the output less crowded. 
# We get warnings to increase max_eps or all data will be considered outliers
# It can be useful to see the warnings, but it's obvious anyway if there are 0 clusters
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    ls_cluster =[]
    print(time.asctime())
    for i in np.arange(2,20):
        for j in np.arange(2,6):
            print(i, j)
            print(time.asctime())
            ls_cluster.append(optics_color(pc, pc_colors, 10**((i*1.0)-4), 2**j))
    print(time.asctime())
# Out:
# Tue May  4 14:30:32 2021
# 2 2
# Tue May  4 14:30:32 2021
# point cloud has 0 clusters
# 2 3
# Tue May  4 14:30:33 2021
# point cloud has 0 clusters
# 2 4
# Tue May  4 14:30:35 2021
# point cloud has 0 clusters
# 2 5
# Tue May  4 14:30:36 2021
# point cloud has 0 clusters
# 3 2
# Tue May  4 14:30:38 2021
# point cloud has 1501 clusters
# 3 3
# Tue May  4 14:31:25 2021
# point cloud has 373 clusters
# 3 4
# Tue May  4 14:32:09 2021
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e0576717f778> in <module>
#      11             print(i, j)
#      12             print(time.asctime())
# ---> 13             ls_cluster.append(optics_color(pc, pc_colors, 10**((i*1.0)-4), 2**j))
#      14     print(time.asctime())
#
# <ipython-input-2-bad7494fc90a> in optics_color(point_cloud, pc_colors, eps, mp, debug)
#      35
#      36     point_cloud = np.asarray(point_cloud.points)
# ---> 37     clustering = OPTICS(min_samples=mp, max_eps=eps, n_jobs=-1).fit(pc_colors)
#      38     labels = clustering.labels_
#      39
#
# ~/.local/lib/python3.8/site-packages/sklearn/cluster/_optics.py in fit(self, X, y)
#     252
#     253         (self.ordering_, self.core_distances_, self.reachability_,
# --> 254          self.predecessor_) = compute_optics_graph(
#     255              X=X, min_samples=self.min_samples, algorithm=self.algorithm,
#     256              leaf_size=self.leaf_size, metric=self.metric,
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.8/site-packages/sklearn/cluster/_optics.py in compute_optics_graph(X, min_samples, max_eps, metric, p, metric_params, algorithm, leaf_size, n_jobs)
#     490         ordering[ordering_idx] = point
#     491         if core_distances_[point] != np.inf:
# --> 492             _set_reach_dist(core_distances_=core_distances_,
#     493                             reachability_=reachability_,
#     494                             predecessor_=predecessor_,
#
# ~/.local/lib/python3.8/site-packages/sklearn/cluster/_optics.py in _set_reach_dist(core_distances_, reachability_, predecessor_, point_index, processed, X, nbrs, metric, metric_params, p, max_eps)
#     511     # and we don't need all distances, nevertheless, this means
#     512     # we may be doing some work twice.
# --> 513     indices = nbrs.radius_neighbors(P, radius=max_eps,
#     514                                     return_distance=False)[0]
#     515
#
# ~/.local/lib/python3.8/site-packages/sklearn/neighbors/_base.py in radius_neighbors(self, X, radius, return_distance, sort_results)
#    1047                 parallel_kwargs = {"prefer": "threads"}
#    1048
# -> 1049             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#    1050                 delayed_query(self._tree, X[s], radius, return_distance,
#    1051                               sort_results=sort_results)
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
#    1042                 self._iterating = self._original_iterator is not None
#    1043
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     250     def apply_async(self, func, callback=None):
#     251         """Schedule a func to be run"""
# --> 252         return self._get_pool().apply_async(
#     253             SafeFunction(func), callback=callback)
#     254
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in _get_pool(self)
#     405         """
#     406         if self._pool is None:
# --> 407             self._pool = ThreadPool(self._n_jobs)
#     408         return self._pool
#     409
#
# /usr/lib/python3.8/multiprocessing/pool.py in __init__(self, processes, initializer, initargs)
#     923
#     924     def __init__(self, processes=None, initializer=None, initargs=()):
# --> 925         Pool.__init__(self, processes, initializer, initargs)
#     926
#     927     def _setup_queues(self):
#
# /usr/lib/python3.8/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     194         # when the cache (self._cache) is empty or when there is a change in
#     195         # the _state variable of the thread that runs _handle_workers.
# --> 196         self._change_notifier = self._ctx.SimpleQueue()
#     197         self._cache = _PoolCache(notifier=self._change_notifier)
#     198         self._maxtasksperchild = maxtasksperchild
#
# /usr/lib/python3.8/multiprocessing/context.py in SimpleQueue(self)
#     111         '''Returns a queue object'''
#     112         from .queues import SimpleQueue
# --> 113         return SimpleQueue(ctx=self.get_context())
#     114
#     115     def Pool(self, processes=None, initializer=None, initargs=(),
#
# /usr/lib/python3.8/multiprocessing/queues.py in __init__(self, ctx)
#     334     def __init__(self, *, ctx):
#     335         self._reader, self._writer = connection.Pipe(duplex=False)
# --> 336         self._rlock = ctx.Lock()
#     337         self._poll = self._reader.poll
#     338         if sys.platform == 'win32':
#
# /usr/lib/python3.8/multiprocessing/context.py in Lock(self)
#      66         '''Returns a non-recursive lock object'''
#      67         from .synchronize import Lock
# ---> 68         return Lock(ctx=self.get_context())
#      69
#      70     def RLock(self):
#
# /usr/lib/python3.8/multiprocessing/synchronize.py in __init__(self, ctx)
#     160
#     161     def __init__(self, *, ctx):
# --> 162         SemLock.__init__(self, SEMAPHORE, 1, 1, ctx=ctx)
#     163
#     164     def __repr__(self):
#
# /usr/lib/python3.8/multiprocessing/synchronize.py in __init__(self, kind, value, maxvalue, ctx)
#      66
#      67         util.debug('created semlock with handle %s' % sl.handle)
# ---> 68         self._make_methods()
#      69
#      70         if sys.platform != 'win32':
#
# /usr/lib/python3.8/multiprocessing/synchronize.py in _make_methods(self)
#      88         unregister(name, "semaphore")
#      89
# ---> 90     def _make_methods(self):
#      91         self.acquire = self._semlock.acquire
#      92         self.release = self._semlock.release
#
# KeyboardInterrupt:

# %%
i=17
j=4
clustered_pc, labels = optics_color(pc, pc_colors, 10**(i-4), 2**j, False)
o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# point cloud has 51 clusters

# %%
# Ignore warnings and make the output less crowded. 
# We get warnings to increase max_eps or all data will be considered outliers
# It can be useful to see the warnings, but it's obvious anyway if there are 0 clusters
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    ls_cluster =[]
    print(time.asctime())
    for i in np.arange(5,20):
        for j in np.arange(2,6):
            print(i, j)
            ls_cluster.append(optics_color(pc, pc_colors, 10**((i*1.0)-4), 2**j))
    print(time.asctime())
# Out:
# Sun Apr 25 15:37:57 2021
# 5 2
# point cloud has 1486 clusters
# 5 3
# point cloud has 316 clusters
# 5 4
# point cloud has 71 clusters
# 5 5
# point cloud has 8 clusters
# 6 2
# point cloud has 1486 clusters
# 6 3
# point cloud has 316 clusters
# 6 4
# point cloud has 71 clusters
# 6 5
# point cloud has 8 clusters
# 7 2
# point cloud has 1486 clusters
# 7 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-d6f5c9624503> in <module>
#      10         for j in np.arange(2,6):
#      11             print(i, j)
# ---> 12             ls_cluster.append(optics_color(pc, pc_colors, 10**((i*1.0)-4), 2**j))
#      13     print(time.asctime())
#
# <ipython-input-30-bad7494fc90a> in optics_color(point_cloud, pc_colors, eps, mp, debug)
#      35
#      36     point_cloud = np.asarray(point_cloud.points)
# ---> 37     clustering = OPTICS(min_samples=mp, max_eps=eps, n_jobs=-1).fit(pc_colors)
#      38     labels = clustering.labels_
#      39
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_optics.py in fit(self, X, y)
#     252
#     253         (self.ordering_, self.core_distances_, self.reachability_,
# --> 254          self.predecessor_) = compute_optics_graph(
#     255              X=X, min_samples=self.min_samples, algorithm=self.algorithm,
#     256              leaf_size=self.leaf_size, metric=self.metric,
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_optics.py in compute_optics_graph(X, min_samples, max_eps, metric, p, metric_params, algorithm, leaf_size, n_jobs)
#     490         ordering[ordering_idx] = point
#     491         if core_distances_[point] != np.inf:
# --> 492             _set_reach_dist(core_distances_=core_distances_,
#     493                             reachability_=reachability_,
#     494                             predecessor_=predecessor_,
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/cluster/_optics.py in _set_reach_dist(core_distances_, reachability_, predecessor_, point_index, processed, X, nbrs, metric, metric_params, p, max_eps)
#     511     # and we don't need all distances, nevertheless, this means
#     512     # we may be doing some work twice.
# --> 513     indices = nbrs.radius_neighbors(P, radius=max_eps,
#     514                                     return_distance=False)[0]
#     515
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_base.py in radius_neighbors(self, X, radius, return_distance, sort_results)
#    1047                 parallel_kwargs = {"prefer": "threads"}
#    1048
# -> 1049             chunked_results = Parallel(n_jobs, **parallel_kwargs)(
#    1050                 delayed_query(self._tree, X[s], radius, return_distance,
#    1051                               sort_results=sort_results)
#
# ~/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1062                 self._backend.stop_call()
#    1063             if not self._managed_backend:
# -> 1064                 self._terminate_backend()
#    1065             self._jobs = list()
#    1066             self._pickle_cache = None
#
# ~/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in _terminate_backend(self)
#     755     def _terminate_backend(self):
#     756         if self._backend is not None:
# --> 757             self._backend.terminate()
#     758
#     759     def _dispatch(self, batch):
#
# ~/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in terminate(self)
#     241         if self._pool is not None:
#     242             self._pool.close()
# --> 243             self._pool.terminate()  # terminate does a join()
#     244             self._pool = None
#     245
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in terminate(self)
#     652         util.debug('terminating pool')
#     653         self._state = TERMINATE
# --> 654         self._terminate()
#     655
#     656     def join(self):
#
# ~/anaconda3/lib/python3.8/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     222                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     223                           self._callback, self._args, self._kwargs)
# --> 224                 res = self._callback(*self._args, **self._kwargs)
#     225             self._weakref = self._callback = self._args = \
#     226                             self._kwargs = self._key = None
#
# ~/anaconda3/lib/python3.8/multiprocessing/pool.py in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     704         util.debug('joining worker handler')
#     705         if threading.current_thread() is not worker_handler:
# --> 706             worker_handler.join()
#     707
#     708         # Terminate workers which haven't already finished.
#
# ~/anaconda3/lib/python3.8/threading.py in join(self, timeout)
#    1009
#    1010         if timeout is None:
# -> 1011             self._wait_for_tstate_lock()
#    1012         else:
#    1013             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/lib/python3.8/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1025         if lock is None:  # already determined that the C code is done
#    1026             assert self._is_stopped
# -> 1027         elif lock.acquire(block, timeout):
#    1028             lock.release()
#    1029             self._stop()
#
# KeyboardInterrupt:

# %%
i=6
j=5
clustered_pc, labels = optics_color(pc, pc_colors, 10**(i-4), 2**j, False)
o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# point cloud has 8 clusters

# %%
# Try kmeans
clustered_pc, labels = k_means_color(pc, pc_colors, 6)
o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# point cloud has 6 clusters

# %%
## DBSCAN without color, if needed for comparison

# %%
ls_cluster =[]
print(time.asctime())
for i in range(5):
    for j in range(6):
        print(i, j)
        ls_cluster.append(dbscan(pc, 10**(i-4), 2**j))
print(time.asctime())
# Out:
# Sun Apr 25 14:37:07 2021
# 0 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 26828
# point cloud has 26828 clusters
# 0 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 0 5
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 26828
# point cloud has 26828 clusters
# 1 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 1 5
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 2 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 24847
# point cloud has 24847 clusters
# 2 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1797
# point cloud has 1797 clusters
# 2 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 10
# point cloud has 10 clusters
# 2 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 2 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 2 5
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 0
# point cloud has 0 clusters
# 3 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 3
# point cloud has 3 clusters
# 3 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 3
# point cloud has 3 clusters
# 3 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 3
# point cloud has 3 clusters
# 3 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 3
# point cloud has 3 clusters
# 3 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 2
# point cloud has 2 clusters
# 3 5
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 0
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 1
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 2
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 3
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 4
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# 4 5
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 1
# point cloud has 1 clusters
# Sun Apr 25 14:39:28 2021

# %%
i=2
j=2
clustered_pc = dbscan(pc, 10**(i-4), 2**j, False) # was 6D
o3d.visualization.draw_geometries([clustered_pc], window_name='t')
# Out:
# [Open3D DEBUG] Precompute Neighbours
# [Open3D DEBUG] Done Precompute Neighbours
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 10
# point cloud has 10 clusters

# %%
# TODO: Extract individual leaves and generate mesh 
# The code to generate the mesh is currently in src/outlier_removal.py
# Then everytging is ready I can write a function for each step, 
# which will make the final main file very tidy and readable
